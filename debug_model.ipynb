# %%
import torch
MODEL_PATH = "/home/ziang/code/humanoid_codebase/unitree_rl_gym/logs/V_trimesh_no_push/Jan10_09-08-56_/model_50.pt"
model = torch.load(MODEL_PATH)
print(model)
# Out:
# {'model_state_dict': OrderedDict([('std', tensor([1.0020, 1.0511, 1.0091, 1.0460, 0.9395, 0.9727, 0.9793, 1.0433, 0.9545,
#         1.0259, 1.0772, 1.0392], device='cuda:0')), ('actor.0.weight', tensor([[-0.1732,  0.2054,  0.1044,  ..., -0.0512,  0.0111,  0.0352],
#         [-0.3488,  0.1113, -0.1868,  ...,  0.1969, -0.0395,  0.0386],
#         [-0.0693,  0.0892,  0.1585,  ...,  0.0122, -0.0591, -0.0513],
#         ...,
#         [ 0.0018,  0.0788, -0.0668,  ...,  0.2529,  0.0522, -0.0954],
#         [ 0.1931, -0.0400,  0.0144,  ..., -0.1621,  0.0861,  0.0953],
#         [ 0.1703,  0.0045, -0.0705,  ...,  0.1638,  0.0796,  0.1124]],
#        device='cuda:0')), ('actor.0.bias', tensor([-0.0952, -0.0745, -0.1410, -0.0795, -0.1263,  0.0723, -0.1299, -0.0849,
#         -0.1167,  0.1034, -0.0538,  0.0494, -0.0996, -0.1376,  0.0875,  0.0213,
#         -0.1004, -0.1028, -0.1200, -0.1356,  0.0042,  0.0262,  0.0956, -0.1860,
# ...
